# %%
# !pip install citipy
# Out:
# Processing /Users/trantran/Library/Caches/pip/wheels/72/ae/63/5d03cf6dfe5c0e9328fb73f8b30da1948a06b9cceaf2c68d2d/citipy-0.0.5-py3-none-any.whl
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %%
from citipy import citipy

# %%
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Get the Weather Description and Amount of Precipitation for Each City

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
import requests
requests.__version__
# Out:
# '2.22.0'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Loop Through the List of Cities and Build the City URL

# %% [markdown]
# ## Initialize an Empty List and Counters

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bathsheba
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | kampong thum
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | komsomolskiy
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | gazojak
# Processing Record 14 of Set 1 | omboue
# Processing Record 15 of Set 1 | rafai
# Processing Record 16 of Set 1 | bonavista
# Processing Record 17 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 1 | yaan
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | dunedin
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | salta
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | masunga
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | taucha
# Processing Record 28 of Set 1 | padang
# Processing Record 29 of Set 1 | flinders
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | yulara
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | ghanzi
# Processing Record 38 of Set 1 | corrales
# Processing Record 39 of Set 1 | cayenne
# Processing Record 40 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | boca do acre
# Processing Record 43 of Set 1 | zyryanka
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | brae
# Processing Record 49 of Set 1 | salekhard
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | gizo
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | vao
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | kushiro
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | tessalit
# Processing Record 8 of Set 2 | havelock
# Processing Record 9 of Set 2 | maniitsoq
# Processing Record 10 of Set 2 | nyurba
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | orange cove
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | cidahu
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | grand gaube
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | dongsheng
# Processing Record 19 of Set 2 | poya
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | dryden
# Processing Record 22 of Set 2 | nantucket
# Processing Record 23 of Set 2 | waipawa
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | dakar
# Processing Record 31 of Set 2 | coihaique
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | batemans bay
# Processing Record 40 of Set 2 | plouzane
# Processing Record 41 of Set 2 | faya
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | portland
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | kurilsk
# Processing Record 47 of Set 2 | bonthe
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | aklavik
# Processing Record 1 of Set 3 | cockburn town
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | isangel
# Processing Record 4 of Set 3 | tinskoy
# Processing Record 5 of Set 3 | villa maria
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | luan
# Processing Record 8 of Set 3 | burgeo
# Processing Record 9 of Set 3 | corlu
# Processing Record 10 of Set 3 | karatuzskoye
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | pozo colorado
# Processing Record 13 of Set 3 | port hardy
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | karla
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | hun
# Processing Record 18 of Set 3 | strelice
# Processing Record 19 of Set 3 | alofi
# Processing Record 20 of Set 3 | touros
# Processing Record 21 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 22 of Set 3 | ahipara
# Processing Record 23 of Set 3 | galesong
# Processing Record 24 of Set 3 | buraydah
# Processing Record 25 of Set 3 | honiara
# Processing Record 26 of Set 3 | harpalpur
# Processing Record 27 of Set 3 | nhlangano
# Processing Record 28 of Set 3 | lagoa
# Processing Record 29 of Set 3 | manzil tamim
# City not found. Skipping...
# Processing Record 30 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 3 | poum
# Processing Record 32 of Set 3 | eureka
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | carutapera
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | mnogovershinnyy
# Processing Record 37 of Set 3 | jaipur hat
# City not found. Skipping...
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 3 | vrangel
# Processing Record 41 of Set 3 | svetlyy
# Processing Record 42 of Set 3 | broome
# Processing Record 43 of Set 3 | vestmannaeyjar
# Processing Record 44 of Set 3 | bassila
# Processing Record 45 of Set 3 | koumra
# Processing Record 46 of Set 3 | payo
# Processing Record 47 of Set 3 | airai
# Processing Record 48 of Set 3 | kalmunai
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | bluff
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | marshall
# Processing Record 5 of Set 4 | heidenau
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | honningsvag
# Processing Record 8 of Set 4 | ornskoldsvik
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | mar del plata
# Processing Record 11 of Set 4 | suzu
# City not found. Skipping...
# Processing Record 12 of Set 4 | katangli
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | esperance
# Processing Record 16 of Set 4 | ouesso
# Processing Record 17 of Set 4 | sidi bu zayd
# City not found. Skipping...
# Processing Record 18 of Set 4 | milkovo
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | kyakhta
# Processing Record 21 of Set 4 | krasnyy chikoy
# Processing Record 22 of Set 4 | teya
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 4 | north bend
# Processing Record 28 of Set 4 | moron
# Processing Record 29 of Set 4 | matay
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 4 | ballina
# Processing Record 34 of Set 4 | butaritari
# Processing Record 35 of Set 4 | tiarei
# Processing Record 36 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 37 of Set 4 | xiantao
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 4 | clyde river
# Processing Record 41 of Set 4 | evensk
# Processing Record 42 of Set 4 | kostyantynivka
# Processing Record 43 of Set 4 | slidell
# Processing Record 44 of Set 4 | chicama
# Processing Record 45 of Set 4 | gat
# Processing Record 46 of Set 4 | aranos
# Processing Record 47 of Set 4 | puerto madryn
# Processing Record 48 of Set 4 | atuona
# Processing Record 49 of Set 4 | yermish
# Processing Record 50 of Set 4 | mitu
# Processing Record 1 of Set 5 | kununurra
# Processing Record 2 of Set 5 | pangody
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | daru
# Processing Record 5 of Set 5 | praia
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | punta cardon
# Processing Record 8 of Set 5 | yichang
# Processing Record 9 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 5 | kapit
# Processing Record 11 of Set 5 | quballat
# Processing Record 12 of Set 5 | kapaa
# Processing Record 13 of Set 5 | vila franca do campo
# Processing Record 14 of Set 5 | voloshka
# Processing Record 15 of Set 5 | san cristobal
# Processing Record 16 of Set 5 | peniche
# Processing Record 17 of Set 5 | sibolga
# Processing Record 18 of Set 5 | emba
# Processing Record 19 of Set 5 | barbastro
# Processing Record 20 of Set 5 | catamarca
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | deputatskiy
# Processing Record 23 of Set 5 | asyut
# Processing Record 24 of Set 5 | bam
# Processing Record 25 of Set 5 | bambanglipuro
# Processing Record 26 of Set 5 | kindu
# Processing Record 27 of Set 5 | okhotsk
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | manokwari
# Processing Record 30 of Set 5 | chuy
# Processing Record 31 of Set 5 | malinovoye ozero
# Processing Record 32 of Set 5 | kaeo
# Processing Record 33 of Set 5 | san vicente
# Processing Record 34 of Set 5 | tadine
# Processing Record 35 of Set 5 | sayyan
# Processing Record 36 of Set 5 | miramar
# Processing Record 37 of Set 5 | haileybury
# Processing Record 38 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 39 of Set 5 | iguatemi
# Processing Record 40 of Set 5 | hami
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | savannah bight
# Processing Record 43 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 5 | labuhan
# Processing Record 45 of Set 5 | chapais
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | la ronge
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | vostok
# Processing Record 50 of Set 5 | nome
# Processing Record 1 of Set 6 | yuzhno-sukhokumsk
# Processing Record 2 of Set 6 | la primavera
# Processing Record 3 of Set 6 | marsa matruh
# Processing Record 4 of Set 6 | kidal
# Processing Record 5 of Set 6 | konstantinovka
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | sibu
# Processing Record 9 of Set 6 | bassar
# Processing Record 10 of Set 6 | svetlogorsk
# Processing Record 11 of Set 6 | georgetown
# Processing Record 12 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 6 | pyaozerskiy
# Processing Record 14 of Set 6 | te anau
# Processing Record 15 of Set 6 | kalianget
# Processing Record 16 of Set 6 | kimbe
# Processing Record 17 of Set 6 | palmerston
# Processing Record 18 of Set 6 | chenzhou
# Processing Record 19 of Set 6 | salisbury
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | lasa
# Processing Record 22 of Set 6 | solano
# Processing Record 23 of Set 6 | tasiilaq
# Processing Record 24 of Set 6 | saint-augustin
# Processing Record 25 of Set 6 | tiksi
# Processing Record 26 of Set 6 | noumea
# Processing Record 27 of Set 6 | qasigiannguit
# Processing Record 28 of Set 6 | riyadh
# Processing Record 29 of Set 6 | le port
# Processing Record 30 of Set 6 | halifax
# Processing Record 31 of Set 6 | vilyuysk
# Processing Record 32 of Set 6 | karabulak
# Processing Record 33 of Set 6 | pudozh
# Processing Record 34 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 6 | bambous virieux
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | mosquera
# Processing Record 38 of Set 6 | tuatapere
# Processing Record 39 of Set 6 | belaya gora
# Processing Record 40 of Set 6 | rocha
# Processing Record 41 of Set 6 | beringovskiy
# Processing Record 42 of Set 6 | tooele
# Processing Record 43 of Set 6 | jambol
# City not found. Skipping...
# Processing Record 44 of Set 6 | traverse city
# Processing Record 45 of Set 6 | severo-kurilsk
# Processing Record 46 of Set 6 | zaraza
# Processing Record 47 of Set 6 | kajaani
# Processing Record 48 of Set 6 | bandarbeyla
# Processing Record 49 of Set 6 | atar
# Processing Record 50 of Set 6 | roma
# Processing Record 1 of Set 7 | ribeira grande
# Processing Record 2 of Set 7 | esna
# Processing Record 3 of Set 7 | calabar
# Processing Record 4 of Set 7 | kenema
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | ayan
# Processing Record 7 of Set 7 | tatawin
# Processing Record 8 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 7 | yerbogachen
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | saint george
# Processing Record 13 of Set 7 | mecca
# Processing Record 14 of Set 7 | sabla
# Processing Record 15 of Set 7 | ningyang
# Processing Record 16 of Set 7 | bueno brandao
# Processing Record 17 of Set 7 | port elgin
# Processing Record 18 of Set 7 | scarborough
# Processing Record 19 of Set 7 | tezu
# Processing Record 20 of Set 7 | zheleznodorozhnyy
# Processing Record 21 of Set 7 | tibiri
# Processing Record 22 of Set 7 | betsiamites
# Processing Record 23 of Set 7 | panaba
# Processing Record 24 of Set 7 | nurota
# Processing Record 25 of Set 7 | santo domingo
# Processing Record 26 of Set 7 | staryy krym
# Processing Record 27 of Set 7 | bougouni
# Processing Record 28 of Set 7 | hambantota
# Processing Record 29 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 7 | ouadda
# Processing Record 31 of Set 7 | ryotsu
# Processing Record 32 of Set 7 | abha
# Processing Record 33 of Set 7 | bilibino
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | matagami
# Processing Record 37 of Set 7 | bundaberg
# Processing Record 38 of Set 7 | aleksandrovsk-sakhalinskiy
# Processing Record 39 of Set 7 | neiafu
# Processing Record 40 of Set 7 | liverpool
# Processing Record 41 of Set 7 | lavrentiya
# Processing Record 42 of Set 7 | baiyin
# Processing Record 43 of Set 7 | ligayan
# Processing Record 44 of Set 7 | bontang
# Processing Record 45 of Set 7 | eenhana
# Processing Record 46 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 7 | port keats
# Processing Record 48 of Set 7 | mahebourg
# Processing Record 49 of Set 7 | yar-sale
# Processing Record 50 of Set 7 | mizan teferi
# Processing Record 1 of Set 8 | atkarsk
# Processing Record 2 of Set 8 | tabas
# Processing Record 3 of Set 8 | grindavik
# Processing Record 4 of Set 8 | sampit
# Processing Record 5 of Set 8 | saint-malo
# Processing Record 6 of Set 8 | akhisar
# Processing Record 7 of Set 8 | huarmey
# Processing Record 8 of Set 8 | zhanaozen
# Processing Record 9 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 8 | holme
# Processing Record 11 of Set 8 | baherden
# Processing Record 12 of Set 8 | vaitape
# Processing Record 13 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 8 | hay river
# Processing Record 15 of Set 8 | udachnyy
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | dingle
# Processing Record 18 of Set 8 | viransehir
# Processing Record 19 of Set 8 | mumford
# Processing Record 20 of Set 8 | pauini
# Processing Record 21 of Set 8 | codrington
# Processing Record 22 of Set 8 | mozarlandia
# Processing Record 23 of Set 8 | bayir
# Processing Record 24 of Set 8 | christchurch
# Processing Record 25 of Set 8 | minggang
# Processing Record 26 of Set 8 | maralal
# Processing Record 27 of Set 8 | valparaiso
# Processing Record 28 of Set 8 | newport
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | dongying
# Processing Record 31 of Set 8 | kavieng
# Processing Record 32 of Set 8 | nizhniy tsasuchey
# Processing Record 33 of Set 8 | taoudenni
# Processing Record 34 of Set 8 | conde
# Processing Record 35 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 8 | rock sound
# Processing Record 37 of Set 8 | itarema
# Processing Record 38 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | hualmay
# Processing Record 41 of Set 8 | olafsvik
# Processing Record 42 of Set 8 | salalah
# Processing Record 43 of Set 8 | sotouboua
# Processing Record 44 of Set 8 | nongstoin
# Processing Record 45 of Set 8 | ostrovnoy
# Processing Record 46 of Set 8 | tabou
# Processing Record 47 of Set 8 | camacha
# Processing Record 48 of Set 8 | berea
# Processing Record 49 of Set 8 | itaporanga
# Processing Record 50 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 9 | paamiut
# Processing Record 3 of Set 9 | chifeng
# Processing Record 4 of Set 9 | kavaratti
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | saint-joseph
# Processing Record 7 of Set 9 | gashua
# Processing Record 8 of Set 9 | baculin
# Processing Record 9 of Set 9 | victor harbor
# Processing Record 10 of Set 9 | ust-tsilma
# Processing Record 11 of Set 9 | la palma
# Processing Record 12 of Set 9 | penzance
# Processing Record 13 of Set 9 | bay-khaak
# Processing Record 14 of Set 9 | taltal
# Processing Record 15 of Set 9 | cooma
# Processing Record 16 of Set 9 | zaria
# Processing Record 17 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 9 | san jose
# Processing Record 19 of Set 9 | mpika
# Processing Record 20 of Set 9 | betare oya
# Processing Record 21 of Set 9 | ponta delgada
# Processing Record 22 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 9 | eyl
# Processing Record 24 of Set 9 | inhambane
# Processing Record 25 of Set 9 | bockenem
# Processing Record 26 of Set 9 | ponta do sol
# Processing Record 27 of Set 9 | la plata
# Processing Record 28 of Set 9 | mamlyutka
# Processing Record 29 of Set 9 | shahr-e babak
# Processing Record 30 of Set 9 | glenwood springs
# Processing Record 31 of Set 9 | palmer
# Processing Record 32 of Set 9 | mocuba
# Processing Record 33 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 9 | dzaoudzi
# Processing Record 35 of Set 9 | santa rosa
# Processing Record 36 of Set 9 | puerto del rosario
# Processing Record 37 of Set 9 | magistralnyy
# Processing Record 38 of Set 9 | syracuse
# Processing Record 39 of Set 9 | amberley
# Processing Record 40 of Set 9 | nelson bay
# Processing Record 41 of Set 9 | lata
# Processing Record 42 of Set 9 | dawlatabad
# Processing Record 43 of Set 9 | tema
# Processing Record 44 of Set 9 | pancol
# Processing Record 45 of Set 9 | mormugao
# Processing Record 46 of Set 9 | sabirabad
# Processing Record 47 of Set 9 | kampene
# Processing Record 48 of Set 9 | tres arroyos
# Processing Record 49 of Set 9 | mundra
# Processing Record 50 of Set 9 | seymchan
# Processing Record 1 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 10 | turukhansk
# Processing Record 3 of Set 10 | eugene
# Processing Record 4 of Set 10 | kahului
# Processing Record 5 of Set 10 | hluti
# Processing Record 6 of Set 10 | san patricio
# Processing Record 7 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 10 | itaituba
# Processing Record 9 of Set 10 | nizhniy kuranakh
# Processing Record 10 of Set 10 | tallahassee
# Processing Record 11 of Set 10 | astoria
# Processing Record 12 of Set 10 | buedu
# Processing Record 13 of Set 10 | la cruz
# Processing Record 14 of Set 10 | giresun
# Processing Record 15 of Set 10 | hervey bay
# Processing Record 16 of Set 10 | meulaboh
# Processing Record 17 of Set 10 | wamba
# Processing Record 18 of Set 10 | shima
# Processing Record 19 of Set 10 | axim
# Processing Record 20 of Set 10 | tagusao
# Processing Record 21 of Set 10 | egvekinot
# Processing Record 22 of Set 10 | boralday
# Processing Record 23 of Set 10 | hobyo
# Processing Record 24 of Set 10 | raudeberg
# Processing Record 25 of Set 10 | oia
# Processing Record 26 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 27 of Set 10 | sinegorye
# Processing Record 28 of Set 10 | tukrah
# Processing Record 29 of Set 10 | skala
# Processing Record 30 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 10 | sechura
# Processing Record 32 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | ferrol
# Processing Record 34 of Set 10 | jawhar
# Processing Record 35 of Set 10 | katsuura
# Processing Record 36 of Set 10 | vila
# Processing Record 37 of Set 10 | libreville
# Processing Record 38 of Set 10 | narsaq
# Processing Record 39 of Set 10 | irsha
# Processing Record 40 of Set 10 | rawlins
# Processing Record 41 of Set 10 | comodoro rivadavia
# Processing Record 42 of Set 10 | kurikka
# Processing Record 43 of Set 10 | khasan
# Processing Record 44 of Set 10 | yeppoon
# Processing Record 45 of Set 10 | sao felix do xingu
# Processing Record 46 of Set 10 | messina
# Processing Record 47 of Set 10 | verkhnevilyuysk
# Processing Record 48 of Set 10 | ypsonas
# Processing Record 49 of Set 10 | turayf
# Processing Record 50 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 11 | beira
# Processing Record 2 of Set 11 | brandenburg
# Processing Record 3 of Set 11 | suchiate
# Processing Record 4 of Set 11 | provideniya
# Processing Record 5 of Set 11 | alekseyevka
# Processing Record 6 of Set 11 | fukue
# Processing Record 7 of Set 11 | bojonegoro
# Processing Record 8 of Set 11 | asfi
# Processing Record 9 of Set 11 | calama
# Processing Record 10 of Set 11 | dauriya
# Processing Record 11 of Set 11 | bongandanga
# Processing Record 12 of Set 11 | coos bay
# Processing Record 13 of Set 11 | kutum
# Processing Record 14 of Set 11 | yumen
# Processing Record 15 of Set 11 | inta
# Processing Record 16 of Set 11 | ust-nera
# Processing Record 17 of Set 11 | agirish
# Processing Record 18 of Set 11 | kuching
# Processing Record 19 of Set 11 | ocampo
# Processing Record 20 of Set 11 | pundaguitan
# Processing Record 21 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 11 | grants
# Processing Record 23 of Set 11 | lichuan
# Processing Record 24 of Set 11 | sobolevo
# Processing Record 25 of Set 11 | verkhnyaya inta
# Processing Record 26 of Set 11 | popondetta
# Processing Record 27 of Set 11 | jibuti
# Processing Record 28 of Set 11 | skibotn
# Processing Record 29 of Set 11 | antofagasta
# Processing Record 30 of Set 11 | makakilo city
# Processing Record 31 of Set 11 | yarmouth
# Processing Record 32 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 11 | grootfontein
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 11 | strezhevoy
# Processing Record 39 of Set 11 | saint-georges
# Processing Record 40 of Set 11 | san quintin
# Processing Record 41 of Set 11 | totness
# Processing Record 42 of Set 11 | denpasar
# Processing Record 43 of Set 11 | puerto madero
# Processing Record 44 of Set 11 | pacific grove
# Processing Record 45 of Set 11 | balabac
# Processing Record 46 of Set 11 | rawson
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | guangyuan
# Processing Record 49 of Set 11 | los llanos de aridane
# Processing Record 50 of Set 11 | port shepstone
# Processing Record 1 of Set 12 | korla
# Processing Record 2 of Set 12 | barao de melgaco
# Processing Record 3 of Set 12 | ozinki
# Processing Record 4 of Set 12 | qandala
# Processing Record 5 of Set 12 | letnyaya stavka
# Processing Record 6 of Set 12 | makamba
# Processing Record 7 of Set 12 | prince rupert
# Processing Record 8 of Set 12 | urdoma
# Processing Record 9 of Set 12 | zarakes
# City not found. Skipping...
# Processing Record 10 of Set 12 | safaga
# Processing Record 11 of Set 12 | samarai
# Processing Record 12 of Set 12 | bolobo
# Processing Record 13 of Set 12 | pedro betancourt
# Processing Record 14 of Set 12 | lashio
# Processing Record 15 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 12 | muros
# Processing Record 17 of Set 12 | cabinda
# Processing Record 18 of Set 12 | asarganj
# Processing Record 19 of Set 12 | paita
# Processing Record 20 of Set 12 | zhigansk
# Processing Record 21 of Set 12 | cabo san lucas
# Processing Record 22 of Set 12 | tevaitoa
# Processing Record 23 of Set 12 | novotroitskaya
# Processing Record 24 of Set 12 | tobermory
# Processing Record 25 of Set 12 | batagay-alyta
# Processing Record 26 of Set 12 | tarhunah
# City not found. Skipping...
# Processing Record 27 of Set 12 | alyangula
# Processing Record 28 of Set 12 | sabang
# Processing Record 29 of Set 12 | bereda
# Processing Record 30 of Set 12 | santa vitoria do palmar
# Processing Record 31 of Set 12 | imeni poliny osipenko
# Processing Record 32 of Set 12 | yumbe
# Processing Record 33 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 34 of Set 12 | staryy nadym
# Processing Record 35 of Set 12 | beisfjord
# Processing Record 36 of Set 12 | nairobi
# Processing Record 37 of Set 12 | muscle shoals
# Processing Record 38 of Set 12 | great yarmouth
# Processing Record 39 of Set 12 | lalsk
# Processing Record 40 of Set 12 | simao
# Processing Record 41 of Set 12 | adrar
# Processing Record 42 of Set 12 | marquette
# Processing Record 43 of Set 12 | otane
# Processing Record 44 of Set 12 | korcula
# Processing Record 45 of Set 12 | bend
# Processing Record 46 of Set 12 | ban nahin
# Processing Record 47 of Set 12 | iqaluit
# Processing Record 48 of Set 12 | tigil
# Processing Record 49 of Set 12 | salamiyah
# Processing Record 50 of Set 12 | darhan
# Processing Record 1 of Set 13 | ipixuna
# Processing Record 2 of Set 13 | riacho de santana
# Processing Record 3 of Set 13 | college
# Processing Record 4 of Set 13 | sisimiut
# Processing Record 5 of Set 13 | hantsport
# Processing Record 6 of Set 13 | erzin
# Processing Record 7 of Set 13 | vallenar
# Processing Record 8 of Set 13 | terra santa
# Processing Record 9 of Set 13 | wawa
# Processing Record 10 of Set 13 | hinton
# Processing Record 11 of Set 13 | mananjary
# Processing Record 12 of Set 13 | buala
# Processing Record 13 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 13 | storsteinnes
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | qaqortoq
# Processing Record 17 of Set 13 | port-gentil
# Processing Record 18 of Set 13 | murray bridge
# Processing Record 19 of Set 13 | necochea
# Processing Record 20 of Set 13 | neuquen
# Processing Record 21 of Set 13 | mopipi
# Processing Record 22 of Set 13 | mount gambier
# Processing Record 23 of Set 13 | vitim
# Processing Record 24 of Set 13 | asosa
# Processing Record 25 of Set 13 | morant bay
# Processing Record 26 of Set 13 | san pedro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 570

# %% [markdown]
# ## Convert the array of dictionaries to a Pandas DataFrame.

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.42   19.23     55.99        91         100
# 1  Punta Arenas      CL -53.15  -70.92     35.60        93          94
# 2       Rikitea      PF -23.12 -134.97     70.99        65          58
# 3   Port Alfred      ZA -33.59   26.89     57.99        91          37
# 4       Ushuaia      AR -54.80  -68.30     35.60        80          56
# 5     Bathsheba      BB  13.22  -59.52     82.40        83          40
# 6        Albany      US  42.60  -73.97     81.00        85          30
# 7  Kampong Thum      KH  12.71  104.89     85.93        76          69
# 8        Bethel      US  41.37  -73.41     73.40        73           1
# 9  Komsomolskiy      UZ  40.43   71.72     71.60        35           0
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        3.00     overcast clouds           0.00              0
# 1        4.70     overcast clouds           0.00              0
# 2       17.29       broken clouds           0.00              0
# 3        4.00    scattered clouds           0.00              0
# 4        5.82       broken clouds           0.00              0
# 5       20.80                haze           0.00              0
# 6        2.84    scattered clouds           0.00              0
# 7        6.15       moderate rain           1.31              0
# 8        6.93           clear sky           0.00              0
# 9        4.70           clear sky           0.00              0

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 7   Kampong Thum      KH  12.71  104.89     85.93        76          69
# 16          Yaan      NG   7.38    8.57     70.18        98         100
# 26        Padang      ID  -0.95  100.35     80.71        76          92
# 43   New Norfolk      AU -42.78  147.06     55.99        93         100
# 47          Gizo      SB  -8.10  156.84     84.22        72           6
# 63     Dongsheng      CN  39.82  109.98     60.62        76         100
# 71          Hilo      US  19.73 -155.09     80.60        57          90
# 73        Hobart      AU -42.88  147.33     55.99        93          75
# 79          Hofn      IS  64.25  -15.21     49.12        93         100
# 89        Bonthe      SL   7.53  -12.51     77.81        87         100
#
#     Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 7         6.15                moderate rain           1.31              0
# 16        6.44                   light rain           0.15              0
# 26        4.50                   light rain           0.15              0
# 43        1.66                moderate rain           1.52              0
# 47        5.66                   light rain           0.13              0
# 63       15.08                   light rain           0.29              0
# 71       10.29                moderate rain           2.29              0
# 73       12.75  light intensity shower rain           0.89              0
# 79       12.44                moderate rain           1.62              0
# 89        4.27                   light rain           0.26              0

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(10)
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %% [markdown]
# ## Create the output file (CSV)

# %%
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
